# %% [markdown]
# <a href="https://colab.research.google.com/github/mn-agalya/Data-Analysis/blob/main/Copy_of_Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Welcome to Colab!
#
# ## Explore the Gemini API
# The Gemini API gives you access to Gemini models created by Google DeepMind. Gemini models are built from the ground up to be multimodal, so you can reason seamlessly across text, images, code, and audio.
#
# **How to get started?**
# *  Go to [Google AI Studio](https://aistudio.google.com/) and log in with your Google account.
# *  [Create an API key](https://aistudio.google.com/app/apikey).
# * Use a quickstart for [Python](https://colab.research.google.com/github/google-gemini/cookbook/blob/main/quickstarts/Get_started.ipynb), or call the REST API using [curl](https://colab.research.google.com/github/google-gemini/cookbook/blob/main/quickstarts/rest/Prompting_REST.ipynb).
#
# **Discover Gemini's advanced capabilities**
# *  Play with Gemini [multimodal outputs](https://colab.research.google.com/github/google-gemini/cookbook/blob/main/quickstarts/Image-out.ipynb), mixing text and images in an iterative way.
# *  Discover the [multimodal Live API](https://colab.research.google.com/github/google-gemini/cookbook/blob/main/quickstarts/Get_started_LiveAPI.ipynb ) (demo [here](https://aistudio.google.com/live)).
# *  Learn how to [analyze images and detect items in your pictures](https://colab.research.google.com/github/google-gemini/cookbook/blob/main/quickstarts/Spatial_understanding.ipynb") using Gemini (bonus, there's a [3D version](https://colab.research.google.com/github/google-gemini/cookbook/blob/main/examples/Spatial_understanding_3d.ipynb) as well!).
# *  Unlock the power of [Gemini thinking model](https://colab.research.google.com/github/google-gemini/cookbook/blob/main/quickstarts/Get_started_thinking.ipynb), capable of solving complex task with its inner thoughts.
#
# **Explore complex use cases**
# *  Use [Gemini grounding capabilities](https://colab.research.google.com/github/google-gemini/cookbook/blob/main/examples/Search_grounding_for_research_report.ipynb) to create a report on a company based on what the model can find on internet.
# *  Extract [invoices and form data from PDF](https://colab.research.google.com/github/google-gemini/cookbook/blob/main/examples/Pdf_structured_outputs_on_invoices_and_forms.ipynb) in a structured way.
# *  Create [illustrations based on a whole book](https://colab.research.google.com/github/google-gemini/cookbook/blob/main/examples/Book_illustration.ipynb) using Gemini large context window and Imagen.
#
# To learn more, check out the [Gemini cookbook](https://github.com/google-gemini/cookbook) or visit the [Gemini API documentation](https://ai.google.dev/docs/).

# %% [markdown]
# Colab now has AI features powered by [Gemini](https://gemini.google.com). The video below provides information on how to use these features, whether you're new to Python, or a seasoned veteran.
#
# <center>
#   <a href="https://www.youtube.com/watch?v=V7RXyqFUR98" target="_blank">
#   <img alt='Thumbnail for a video showing 3 AI-powered Google Colab features' src="data:image/png;base64,..." height="188" width="336">
#   </a>
# </center>

# %% [markdown]
# <div class="markdown-google-sans">
#   <h2>What is Colab?</h2>
# </div>
#
# Colab, or "Colaboratory", allows you to write and execute Python in your browser, with
# - Zero configuration required
# - Access to GPUs free of charge
# - Easy sharing
#
# Whether you're a **student**, a **data scientist** or an **AI researcher**, Colab can make your work easier. Watch [Introduction to Colab](https://www.youtube.com/watch?v=inN8seMm7UI) or [Colab Features You May Have Missed](https://www.youtube.com/watch?v=rNgswRZ2C1Y) to learn more, or just get started below!

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## **Getting started**
# </div>
#
# The document you are reading is not a static web page, but an interactive environment called a **Colab notebook** that lets you write and execute code.
#
# For example, here is a **code cell** with a short Python script that computes a value, stores it in a variable, and prints the result:

# %%
seconds_in_a_day = 24 * 60 * 60
seconds_in_a_day
# Out:
# 86400

# %% [markdown]
# To execute the code in the above cell, select it with a click and then either press the play button to the left of the code, or use the keyboard shortcut "Command/Ctrl+Enter". To edit the code, just click the cell and start editing.
#
# Variables that you define in one cell can later be used in other cells:

# %%
seconds_in_a_week = 7 * seconds_in_a_day
seconds_in_a_week
# Out:
# 604800

# %% [markdown]
# Colab notebooks allow you to combine **executable code** and **rich text** in a single document, along with **images**, **HTML**, **LaTeX** and more. When you create your own Colab notebooks, they are stored in your Google Drive account. You can easily share your Colab notebooks with co-workers or friends, allowing them to comment on your notebooks or even edit them. To learn more, see [Overview of Colab](/notebooks/basic_features_overview.ipynb). To create a new Colab notebook you can use the File menu above, or use the following link: [create a new Colab notebook](http://colab.research.google.com#create=true).
#
# Colab notebooks are Jupyter notebooks that are hosted by Colab. To learn more about the Jupyter project, see [jupyter.org](https://www.jupyter.org).

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## Data science
# </div>
#
# With Colab you can harness the full power of popular Python libraries to analyze and visualize data. The code cell below uses **numpy** to generate some random data, and uses **matplotlib** to visualize it. To edit the code, just click the cell and start editing.

# %% [markdown]
# You can import your own data into Colab notebooks from your Google Drive account, including from spreadsheets, as well as from Github and many other sources. To learn more about importing data, and how Colab can be used for data science, see the links below under [Working with Data](#working-with-data).

# %%
import numpy as np
import IPython.display as display
from matplotlib import pyplot as plt
import io
import base64

ys = 200 + np.random.randn(100)
x = [x for x in range(len(ys))]

fig = plt.figure(figsize=(4, 3), facecolor='w')
plt.plot(x, ys, '-')
plt.fill_between(x, ys, 195, where=(ys > 195), facecolor='g', alpha=0.6)
plt.title("Sample Visualization", fontsize=10)

data = io.BytesIO()
plt.savefig(data)
image = F"data:image/png;base64,{base64.b64encode(data.getvalue()).decode()}"
alt = "Sample Visualization"
display.display(display.Markdown(F"""![{alt}]({image})"""))
plt.close(fig)
# Out:
# ![Sample Visualization](data:image/png;base64,...)

# %% [markdown]
# Colab notebooks execute code on Google's cloud servers, meaning you can leverage the power of Google hardware, including [GPUs and TPUs](#using-accelerated-hardware), regardless of the power of your machine. All you need is a browser.
#
# For example, if you find yourself waiting for **pandas** code to finish running and want to go faster, you can switch to a GPU Runtime and use libraries like [RAPIDS cuDF](https://rapids.ai/cudf-pandas) that provide zero-code-change acceleration.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# !pip install plotly
import plotly.express as px
# Out:
# Requirement already satisfied: plotly in /usr/local/lib/python3.11/dist-packages (5.24.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly) (9.1.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from plotly) (24.2)

# %%
import pandas as pd
df=pd.read_csv('Ecommerce_data.csv')
df
# Out:
#        customer_id customer_first_name customer_last_name    category_name  \
# 0       C_ID_45866                Mary             Fuller  Office Supplies
# 1       C_ID_44932                Alan            Edelman  Office Supplies
# 2       C_ID_70880                Mary             Gayman  Office Supplies
# 3       C_ID_33157             Raymond              Eason  Office Supplies
# 4       C_ID_58303                Mary           Gonzalez        Furniture
# ...            ...                 ...                ...              ...
# 113265  C_ID_34871                Mary               Bern  Office Supplies
# 113266  C_ID_37639                 Zia            Stivers  Office Supplies
# 113267  C_ID_35727               David         Schnelling        Furniture
# 113268  C_ID_35327               Amber           Hamilton        Furniture
# 113269  C_ID_35727              Robert               Reed        Furniture
#
#                                              product_name customer_segment  \
# 0                                              Xerox 1913        Corporate
# 1                      #6 3/4 Gummed Flap White Envelopes        Corporate
# 2                         Belkin 8 Outlet Surge Protector         Consumer
# 3                    GBC VeloBinder Manual Binding System        Corporate
# 4                           Eldon Pizzaz Desk Accessories      Home Office
# ...                                                   ...              ...
# 113265  Sortfiler Multipurpose Personal File Organizer...         Consumer
# 113266  Acme Hot Forged Carbon Steel Scissors with Nic...        Corporate
# 113267          Global High-Back Leather Tilter, Burgundy        Corporate
# 113268            Bevis Round Bullnose 29" High Table Top         Consumer
# 113269            Bevis Round Bullnose 29" High Table Top         Consumer
#
#         customer_city customer_state customer_country customer_region  ...  \
# 0        New Rochelle       New York    United States            East  ...
# 1             Houston          Texas    United States         Central  ...
# 2          Louisville       Kentucky    United States           South  ...
# 3             Chicago       Illinois    United States         Central  ...
# 4        Philadelphia   Pennsylvania    United States            East  ...
# ...               ...            ...              ...             ...  ...
# 113265  New York City       New York    United States            East  ...
# 113266        Hampton       Virginia    United States           South  ...
# 113267        Dubuque           Iowa    United States         Central  ...
# 113268  New York City       New York    United States            East  ...
# 113269    Springfield       Missouri    United States         Central  ...
#
#         order_date      order_id   ship_date   shipping_type  \
# 0        11/5/2022  O_ID_3001072   11/7/2022    Second Class
# 1       20-06-2022  O_ID_3009170  23-06-2022    Second Class
# 2       25-06-2022  O_ID_3047567  30-06-2022  Standard Class
# 3        10/6/2022  O_ID_3060575  10/10/2022    Second Class
# 4         2/5/2022  O_ID_3064311    8/1/2022     First Class
# ...            ...           ...         ...             ...
# 113265   12/4/2021  O_ID_3113465   12/8/2021    Second Class
# 113266  19-12-2022  O_ID_3113466  23-12-2022    Second Class
# 113267  17-03-2021  O_ID_3113467  21-03-2021    Second Class
# 113268    4/4/2021  O_ID_3113468    4/8/2021    Second Class
# 113269  28-02-2021  O_ID_3113469    4/3/2021    Second Class
#
#        days_for_shipment_scheduled  days_for_shipment_real  \
# 0                                2                       2
# 1                                2                       3
# 2                                4                       5
# 3                                2                       4
# 4                                1                       2
# ...                            ...                     ...
# 113265                           2                       4
# 113266                           2                       4
# 113267                           2                       4
# 113268                           2                       4
# 113269                           2                       4
#
#         order_item_discount  sales_per_order  order_quantity  profit_per_order
# 0                     35.00       500.000000               5        223.199997
# 1                     85.00       500.000000               5        199.199997
# 2                     75.00        44.000000               5        195.500000
# 3                     60.00       254.000000               1        220.000000
# 4                    125.00       500.000000               1         97.500000
# ...                     ...              ...             ...               ...
# 113265                32.00       199.990005               1         75.599998
# 113266                 5.28        31.080000               1         12.900000
# 113267                36.00       199.990005               1        -10.330000
# 113268                60.00       299.980011               1         -3.360000
# 113269                26.00       129.990005               1         46.799999
#
# [113270 rows x 21 columns]

# %%
df.head()
# Out:
#   customer_id customer_first_name customer_last_name    category_name  \
# 0  C_ID_45866                Mary             Fuller  Office Supplies
# 1  C_ID_44932                Alan            Edelman  Office Supplies
# 2  C_ID_70880                Mary             Gayman  Office Supplies
# 3  C_ID_33157             Raymond              Eason  Office Supplies
# 4  C_ID_58303                Mary           Gonzalez        Furniture
#
#                            product_name customer_segment customer_city  \
# 0                            Xerox 1913        Corporate  New Rochelle
# 1    #6 3/4 Gummed Flap White Envelopes        Corporate       Houston
# 2       Belkin 8 Outlet Surge Protector         Consumer    Louisville
# 3  GBC VeloBinder Manual Binding System        Corporate       Chicago
# 4         Eldon Pizzaz Desk Accessories      Home Office  Philadelphia
#
#   customer_state customer_country customer_region  ...  order_date  \
# 0       New York    United States            East  ...   11/5/2022
# 1          Texas    United States         Central  ...  20-06-2022
# 2       Kentucky    United States           South  ...  25-06-2022
# 3       Illinois    United States         Central  ...   10/6/2022
# 4   Pennsylvania    United States            East  ...    2/5/2022
#
#        order_id   ship_date   shipping_type days_for_shipment_scheduled  \
# 0  O_ID_3001072   11/7/2022    Second Class                           2
# 1  O_ID_3009170  23-06-2022    Second Class                           2
# 2  O_ID_3047567  30-06-2022  Standard Class                           4
# 3  O_ID_3060575  10/10/2022    Second Class                           2
# 4  O_ID_3064311    8/1/2022     First Class                           1
#
#    days_for_shipment_real  order_item_discount  sales_per_order  \
# 0                       2                 35.0            500.0
# 1                       3                 85.0            500.0
# 2                       5                 75.0             44.0
# 3                       4                 60.0            254.0
# 4                       2                125.0            500.0
#
#    order_quantity  profit_per_order
# 0               5        223.199997
# 1               5        199.199997
# 2               5        195.500000
# 3               1        220.000000
# 4               1         97.500000
#
# [5 rows x 21 columns]

# %%
df.tail()
# Out:
#        customer_id customer_first_name customer_last_name    category_name  \
# 113265  C_ID_34871                Mary               Bern  Office Supplies
# 113266  C_ID_37639                 Zia            Stivers  Office Supplies
# 113267  C_ID_35727               David         Schnelling        Furniture
# 113268  C_ID_35327               Amber           Hamilton        Furniture
# 113269  C_ID_35727              Robert               Reed        Furniture
#
#                                              product_name customer_segment  \
# 113265  Sortfiler Multipurpose Personal File Organizer...         Consumer
# 113266  Acme Hot Forged Carbon Steel Scissors with Nic...        Corporate
# 113267          Global High-Back Leather Tilter, Burgundy        Corporate
# 113268            Bevis Round Bullnose 29" High Table Top         Consumer
# 113269            Bevis Round Bullnose 29" High Table Top         Consumer
#
#         customer_city customer_state customer_country customer_region  ...  \
# 113265  New York City       New York    United States            East  ...
# 113266        Hampton       Virginia    United States           South  ...
# 113267        Dubuque           Iowa    United States         Central  ...
# 113268  New York City       New York    United States            East  ...
# 113269    Springfield       Missouri    United States         Central  ...
#
#         order_date      order_id   ship_date shipping_type  \
# 113265   12/4/2021  O_ID_3113465   12/8/2021  Second Class
# 113266  19-12-2022  O_ID_3113466  23-12-2022  Second Class
# 113267  17-03-2021  O_ID_3113467  21-03-2021  Second Class
# 113268    4/4/2021  O_ID_3113468    4/8/2021  Second Class
# 113269  28-02-2021  O_ID_3113469    4/3/2021  Second Class
#
#        days_for_shipment_scheduled  days_for_shipment_real  \
# 113265                           2                       4
# 113266                           2                       4
# 113267                           2                       4
# 113268                           2                       4
# 113269                           2                       4
#
#         order_item_discount  sales_per_order  order_quantity  profit_per_order
# 113265                32.00       199.990005               1         75.599998
# 113266                 5.28        31.080000               1         12.900000
# 113267                36.00       199.990005               1        -10.330000
# 113268                60.00       299.980011               1         -3.360000
# 113269                26.00       129.990005               1         46.799999
#
# [5 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113270 entries, 0 to 113269
# Data columns (total 21 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   customer_id                  113270 non-null  object
#  1   customer_first_name          113270 non-null  object
#  2   customer_last_name           113270 non-null  object
#  3   category_name                113270 non-null  object
#  4   product_name                 113270 non-null  object
#  5   customer_segment             113270 non-null  object
#  6   customer_city                113270 non-null  object
#  7   customer_state               113270 non-null  object
#  8   customer_country             113270 non-null  object
#  9   customer_region              113270 non-null  object
#  10  delivery_status              113270 non-null  object
#  11  order_date                   113270 non-null  object
#  12  order_id                     113270 non-null  object
#  13  ship_date                    113270 non-null  object
#  14  shipping_type                113270 non-null  object
#  15  days_for_shipment_scheduled  113270 non-null  int64
#  16  days_for_shipment_real       113270 non-null  int64
#  17  order_item_discount          113270 non-null  float64
#  18  sales_per_order              113270 non-null  float64
#  19  order_quantity               113270 non-null  int64
#  20  profit_per_order             113270 non-null  float64
# dtypes: float64(3), int64(3), object(15)
# memory usage: 18.1+ MB

# %%
df.describe()
# Out:
#        days_for_shipment_scheduled  days_for_shipment_real  \
# count                113270.000000           113270.000000
# mean                      2.931209                3.464006
# std                       1.375914                1.632198
# min                       0.000000                0.000000
# 25%                       2.000000                2.000000
# 50%                       4.000000                3.000000
# 75%                       4.000000                5.000000
# max                       4.000000                6.000000
#
#        order_item_discount  sales_per_order  order_quantity  profit_per_order
# count        113270.000000    113270.000000   113270.000000     113270.000000
# mean             21.105465       204.499537        1.967564         23.069382
# std              22.959207       141.443090        1.355254        105.288561
# min               0.000000         9.990000        1.000000      -3366.000000
# 25%               5.500000       119.980003        1.000000          7.200000
# 50%              14.400000       199.919998        1.000000         32.029999
# 75%              30.000000       299.950012        3.000000         65.570000
# max             500.000000      1999.989990        5.000000       2600.000000

# %%
df['customer_segment'].value_counts()
# Out:
# customer_segment
# Consumer       58714
# Corporate      34322
# Home Office    20234
# Name: count, dtype: int64

# %%
df['customer_region'].unique()
# Out:
# array(['East', 'Central', 'South', 'West'], dtype=object)

# %%
df.isnull()
# Out:
#         customer_id  customer_first_name  customer_last_name  category_name  \
# 0             False                False               False          False
# 1             False                False               False          False
# 2             False                False               False          False
# 3             False                False               False          False
# 4             False                False               False          False
# ...             ...                  ...                 ...            ...
# 113265        False                False               False          False
# 113266        False                False               False          False
# 113267        False                False               False          False
# 113268        False                False               False          False
# 113269        False                False               False          False
#
#         product_name  customer_segment  customer_city  customer_state  \
# 0              False             False          False           False
# 1              False             False          False           False
# 2              False             False          False           False
# 3              False             False          False           False
# 4              False             False          False           False
# ...              ...               ...            ...             ...
# 113265         False             False          False           False
# 113266         False             False          False           False
# 113267         False             False          False           False
# 113268         False             False          False           False
# 113269         False             False          False           False
#
#         customer_country  customer_region  ...  order_date  order_id  \
# 0                  False            False  ...       False     False
# 1                  False            False  ...       False     False
# 2                  False            False  ...       False     False
# 3                  False            False  ...       False     False
# 4                  False            False  ...       False     False
# ...                  ...              ...  ...         ...       ...
# 113265             False            False  ...       False     False
# 113266             False            False  ...       False     False
# 113267             False            False  ...       False     False
# 113268             False            False  ...       False     False
# 113269             False            False  ...       False     False
#
#         ship_date  shipping_type  days_for_shipment_scheduled  \
# 0           False          False                        False
# 1           False          False                        False
# 2           False          False                        False
# 3           False          False                        False
# 4           False          False                        False
# ...           ...            ...                          ...
# 113265      False          False                        False
# 113266      False          False                        False
# 113267      False          False                        False
# 113268      False          False                        False
# 113269      False          False                        False
#
#         days_for_shipment_real  order_item_discount  sales_per_order  \
# 0                        False                False            False
# 1                        False                False            False
# 2                        False                False            False
# 3                        False                False            False
# 4                        False                False            False
# ...                        ...                  ...              ...
# 113265                   False                False            False
# 113266                   False                False            False
# 113267                   False                False            False
# 113268                   False                False            False
# 113269                   False                False            False
#
#         order_quantity  profit_per_order
# 0                False             False
# 1                False             False
# 2                False             False
# 3                False             False
# 4                False             False
# ...                ...               ...
# 113265           False             False
# 113266           False             False
# 113267           False             False
# 113268           False             False
# 113269           False             False
#
# [113270 rows x 21 columns]

# %%
df.isnull().sum()
# Out:
# customer_id                    0
# customer_first_name            0
# customer_last_name             0
# category_name                  0
# product_name                   0
# customer_segment               0
# customer_city                  0
# customer_state                 0
# customer_country               0
# customer_region                0
# delivery_status                0
# order_date                     0
# order_id                       0
# ship_date                      0
# shipping_type                  0
# days_for_shipment_scheduled    0
# days_for_shipment_real         0
# order_item_discount            0
# sales_per_order                0
# order_quantity                 0
# profit_per_order               0
# dtype: int64

# %%
df.notnull()
# Out:
#         customer_id  customer_first_name  customer_last_name  category_name  \
# 0              True                 True                True           True
# 1              True                 True                True           True
# 2              True                 True                True           True
# 3              True                 True                True           True
# 4              True                 True                True           True
# ...             ...                  ...                 ...            ...
# 113265         True                 True                True           True
# 113266         True                 True                True           True
# 113267         True                 True                True           True
# 113268         True                 True                True           True
# 113269         True                 True                True           True
#
#         product_name  customer_segment  customer_city  customer_state  \
# 0               True              True           True            True
# 1               True              True           True            True
# 2               True              True           True            True
# 3               True              True           True            True
# 4               True              True           True            True
# ...              ...               ...            ...             ...
# 113265          True              True           True            True
# 113266          True              True           True            True
# 113267          True              True           True            True
# 113268          True              True           True            True
# 113269          True              True           True            True
#
#         customer_country  customer_region  ...  order_date  order_id  \
# 0                   True             True  ...        True      True
# 1                   True             True  ...        True      True
# 2                   True             True  ...        True      True
# 3                   True             True  ...        True      True
# 4                   True             True  ...        True      True
# ...                  ...              ...  ...         ...       ...
# 113265              True             True  ...        True      True
# 113266              True             True  ...        True      True
# 113267              True             True  ...        True      True
# 113268              True             True  ...        True      True
# 113269              True             True  ...        True      True
#
#         ship_date  shipping_type  days_for_shipment_scheduled  \
# 0            True           True                         True
# 1            True           True                         True
# 2            True           True                         True
# 3            True           True                         True
# 4            True           True                         True
# ...           ...            ...                          ...
# 113265       True           True                         True
# 113266       True           True                         True
# 113267       True           True                         True
# 113268       True           True                         True
# 113269       True           True                         True
#
#         days_for_shipment_real  order_item_discount  sales_per_order  \
# 0                         True                 True             True
# 1                         True                 True             True
# 2                         True                 True             True
# 3                         True                 True             True
# 4                         True                 True             True
# ...                        ...                  ...              ...
# 113265                    True                 True             True
# 113266                    True                 True             True
# 113267                    True                 True             True
# 113268                    True                 True             True
# 113269                    True                 True             True
#
#         order_quantity  profit_per_order
# 0                 True              True
# 1                 True              True
# 2                 True              True
# 3                 True              True
# 4                 True              True
# ...                ...               ...
# 113265            True              True
# 113266            True              True
# 113267            True              True
# 113268            True              True
# 113269            True              True
#
# [113270 rows x 21 columns]

# %%
df.notnull().sum()
# Out:
# customer_id                    113270
# customer_first_name            113270
# customer_last_name             113270
# category_name                  113270
# product_name                   113270
# customer_segment               113270
# customer_city                  113270
# customer_state                 113270
# customer_country               113270
# customer_region                113270
# delivery_status                113270
# order_date                     113270
# order_id                       113270
# ship_date                      113270
# shipping_type                  113270
# days_for_shipment_scheduled    113270
# days_for_shipment_real         113270
# order_item_discount            113270
# sales_per_order                113270
# order_quantity                 113270
# profit_per_order               113270
# dtype: int64

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [customer_id, customer_first_name, customer_last_name, category_name, product_name, customer_segment, customer_city, customer_state, customer_country, customer_region, delivery_status, order_date, order_id, ship_date, shipping_type, days_for_shipment_scheduled, days_for_shipment_real, order_item_discount, sales_per_order, order_quantity, profit_per_order]
# Index: []
#
# [0 rows x 21 columns]

# %%
df.groupby('customer_segment').agg({'profit_per_order':['mean','sum']})
# Out:
#                  profit_per_order
#                              mean           sum
# customer_segment
# Consumer                23.372028  1.372265e+06
# Corporate               23.009132  7.897194e+05
# Home Office             22.293379  4.510842e+05

# %%
df.sort_values(by='sales_per_order',ascending=False)
# Out:
#       customer_id customer_first_name customer_last_name    category_name  \
# 42866  C_ID_45084               Amber          Vittorini  Office Supplies
# 54638  C_ID_40553                Mary              Bixby  Office Supplies
# 40853  C_ID_72697              Teresa               Hart  Office Supplies
# 4231   C_ID_71167             Richard             Triggs  Office Supplies
# 99984  C_ID_47220                Mary           Ashbrook        Furniture
# ...           ...                 ...                ...              ...
# 62128  C_ID_52479               David            Cousins        Furniture
# 57913  C_ID_26631                Mary             Poddar        Furniture
# 34659  C_ID_35340                Mary             Triggs        Furniture
# 93736  C_ID_70839                Mary         Carmichael  Office Supplies
# 82164  C_ID_62064                Mary             Ferrer  Office Supplies
#
#                                             product_name customer_segment  \
# 42866                                          Newell 34      Home Office
# 54638  Vinyl Coated Wire Paper Clips in Organizer Box...         Consumer
# 40853                  Eldon Shelf Savers Cubes and Bins        Corporate
# 4231           Fellowes Mighty 8 Compact Surge Protector         Consumer
# 99984  Eldon Regeneration Recycled Desk Accessories, ...         Consumer
# ...                                                  ...              ...
# 62128       HON 5400 Series Task Chairs for Big and Tall         Consumer
# 57913      Executive Impressions 14" Contract Wall Clock        Corporate
# 34659  Riverside Furniture Oval Coffee Table, Oval En...        Corporate
# 93736                                           Xerox 22         Consumer
# 82164                          Acco Hanging Data Binders        Corporate
#
#       customer_city        customer_state customer_country customer_region  \
# 42866   Los Angeles            California    United States            West
# 54638    Washington  District of Columbia    United States            East
# 40853        Newark              Delaware    United States            East
# 4231     Long Beach              New York    United States            East
# 99984      Lakeland               Florida    United States           South
# ...             ...                   ...              ...             ...
# 62128       Houston                 Texas    United States         Central
# 57913        Dallas                 Texas    United States         Central
# 34659      Florence               Alabama    United States           South
# 93736        Newark                  Ohio    United States            East
# 82164       Detroit              Michigan    United States         Central
#
#        ...  order_date      order_id   ship_date   shipping_type  \
# 42866  ...  13-02-2022  O_ID_3042944  13-06-2022  Standard Class
# 54638  ...  13-02-2022  O_ID_3054737  13-07-2022    Second Class
# 40853  ...  13-01-2022  O_ID_3040928  13-03-2022  Standard Class
# 4231   ...  13-01-2022  O_ID_3004241  13-04-2022  Standard Class
# 99984  ...   3/10/2022  O_ID_3100165  13-02-2022  Standard Class
# ...    ...         ...           ...         ...             ...
# 62128  ...    3/3/2022  O_ID_3062250    6/6/2022  Standard Class
# 57913  ...  24-11-2021  O_ID_3058023  29-11-2021  Standard Class
# 34659  ...  26-01-2021  O_ID_3034727  28-01-2021    Second Class
# 93736  ...  13-03-2021  O_ID_3093899  13-09-2021  Standard Class
# 82164  ...   1/10/2021  O_ID_3082318  13-03-2021  Standard Class
#
#       days_for_shipment_scheduled  days_for_shipment_real  \
# 42866                           4                       4
# 54638                           2                       5
# 40853                           4                       2
# 4231                            4                       3
# 99984                           4                       2
# ...                           ...                     ...
# 62128                           4                       6
# 57913                           4                       5
# 34659                           2                       2
# 93736                           4                       6
# 82164                           4                       5
#
#        order_item_discount  sales_per_order  order_quantity  profit_per_order
# 42866                140.0       1999.98999               1        139.500000
# 54638                100.0       1999.98999               1        112.000000
# 40853                260.0       1999.98999               1         34.799999
# 4231                 180.0       1999.98999               1        473.200012
# 99984                320.0       1999.98999               4       -952.559998
# ...                    ...              ...             ...               ...
# 62128                  0.5          9.99000               1          2.370000
# 57913                  1.3          9.99000               1          3.560000
# 34659                  1.7          9.99000               1          2.240000
# 93736                  1.6          9.99000               1          3.690000
# 82164                  1.7          9.99000               1          1.040000
#
# [113270 rows x 21 columns]

# %%
df.filter(items=['customer_segment','sales_per_order'])
# Out:
#        customer_segment  sales_per_order
# 0             Corporate       500.000000
# 1             Corporate       500.000000
# 2              Consumer        44.000000
# 3             Corporate       254.000000
# 4           Home Office       500.000000
# ...                 ...              ...
# 113265         Consumer       199.990005
# 113266        Corporate        31.080000
# 113267        Corporate       199.990005
# 113268         Consumer       299.980011
# 113269         Consumer       129.990005
#
# [113270 rows x 2 columns]

# %%
df['delivery_status']=df['delivery_status'].replace({'Late':'Delayed','On-time':'OnTime'})

# %%
df.dropna()
# Out:
#        customer_id customer_first_name customer_last_name    category_name  \
# 0       C_ID_45866                Mary             Fuller  Office Supplies
# 1       C_ID_44932                Alan            Edelman  Office Supplies
# 2       C_ID_70880                Mary             Gayman  Office Supplies
# 3       C_ID_33157             Raymond              Eason  Office Supplies
# 4       C_ID_58303                Mary           Gonzalez        Furniture
# ...            ...                 ...                ...              ...
# 113265  C_ID_34871                Mary               Bern  Office Supplies
# 113266  C_ID_37639                 Zia            Stivers  Office Supplies
# 113267  C_ID_35727               David         Schnelling        Furniture
# 113268  C_ID_35327               Amber           Hamilton        Furniture
# 113269  C_ID_35727              Robert               Reed        Furniture
#
#                                              product_name customer_segment  \
# 0                                              Xerox 1913        Corporate
# 1                      #6 3/4 Gummed Flap White Envelopes        Corporate
# 2                         Belkin 8 Outlet Surge Protector         Consumer
# 3                    GBC VeloBinder Manual Binding System        Corporate
# 4                           Eldon Pizzaz Desk Accessories      Home Office
# ...                                                   ...              ...
# 113265  Sortfiler Multipurpose Personal File Organizer...         Consumer
# 113266  Acme Hot Forged Carbon Steel Scissors with Nic...        Corporate
# 113267          Global High-Back Leather Tilter, Burgundy        Corporate
# 113268            Bevis Round Bullnose 29" High Table Top         Consumer
# 113269            Bevis Round Bullnose 29" High Table Top         Consumer
#
#         customer_city customer_state customer_country customer_region  ...  \
# 0        New Rochelle       New York    United States            East  ...
# 1             Houston          Texas    United States         Central  ...
# 2          Louisville       Kentucky    United States           South  ...
# 3             Chicago       Illinois    United States         Central  ...
# 4        Philadelphia   Pennsylvania    United States            East  ...
# ...               ...            ...              ...             ...  ...
# 113265  New York City       New York    United States            East  ...
# 113266        Hampton       Virginia    United States           South  ...
# 113267        Dubuque           Iowa    United States         Central  ...
# 113268  New York City       New York    United States            East  ...
# 113269    Springfield       Missouri    United States         Central  ...
#
#             order_id   ship_date   shipping_type days_for_shipment_scheduled  \
# 0       O_ID_3001072   11/7/2022    Second Class                           2
# 1       O_ID_3009170  23-06-2022    Second Class                           2
# 2       O_ID_3047567  30-06-2022  Standard Class                           4
# 3       O_ID_3060575  10/10/2022    Second Class                           2
# 4       O_ID_3064311    8/1/2022     First Class                           1
# ...              ...         ...             ...                         ...
# 113265  O_ID_3113465   12/8/2021    Second Class                           2
# 113266  O_ID_3113466  23-12-2022    Second Class                           2
# 113267  O_ID_3113467  21-03-2021    Second Class                           2
# 113268  O_ID_3113468    4/8/2021    Second Class                           2
# 113269  O_ID_3113469    4/3/2021    Second Class                           2
#
#        days_for_shipment_real  order_item_discount  sales_per_order  \
# 0                           2                35.00       500.000000
# 1                           3                85.00       500.000000
# 2                           5                75.00        44.000000
# 3                           4                60.00       254.000000
# 4                           2               125.00       500.000000
# ...                       ...                  ...              ...
# 113265                      4                32.00       199.990005
# 113266                      4                 5.28        31.080000
# 113267                      4                36.00       199.990005
# 113268                      4                60.00       299.980011
# 113269                      4                26.00       129.990005
#
#         order_quantity  profit_per_order  shipment_delay
# 0                    5        223.199997               0
# 1                    5        199.199997               1
# 2                    5        195.500000               1
# 3                    1        220.000000               2
# 4                    1         97.500000               1
# ...                ...               ...             ...
# 113265               1         75.599998               2
# 113266               1         12.900000               2
# 113267               1        -10.330000               2
# 113268               1         -3.360000               2
# 113269               1         46.799999               2
#
# [113270 rows x 22 columns]

# %%
df['cumulative_sales']=df['sales_per_order'].cumsum()

# %%
df.count()
# Out:
# customer_id                    113270
# customer_first_name            113270
# customer_last_name             113270
# category_name                  113270
# product_name                   113270
# customer_segment               113270
# customer_city                  113270
# customer_state                 113270
# customer_country               113270
# customer_region                113270
# delivery_status                113270
# order_date                     113270
# order_id                       113270
# ship_date                      113270
# shipping_type                  113270
# days_for_shipment_scheduled    113270
# days_for_shipment_real         113270
# order_item_discount            113270
# sales_per_order                113270
# order_quantity                 113270
# profit_per_order               113270
# cumulative_sales               113270
# dtype: int64

# %%
df['sales_per_order'].mean()
# Out:
# np.float64(204.49953707653785)

# %%
df['sales_per_order'].median()
# Out:
# 199.9199982

# %%
df['sales_per_order'].mode()
# Out:
# 0    129.990005
# Name: sales_per_order, dtype: float64

# %%
df['sales_per_order'].min()
# Out:
# 9.989999771

# %%
df['sales_per_order'].max()
# Out:
# 1999.98999

# %%
df['sales_per_order'].std()
# Out:
# 141.4430896075609

# %%
df['sales_per_order'].var()
# Out:
# 20006.1475977325

# %%
df['sales_per_order'].quantile(0.90)
# Out:
# np.float64(399.980011)

# %%
df.pivot_table(index='customer_region',values='profit_per_order',aggfunc='mean')
# Out:
#                  profit_per_order
# customer_region
# Central                 22.228666
# East                    23.303761
# South                   22.465101
# West                    23.776942

# %%
df2=df[['customer_id','order_id']].copy()
df_merged=df.merge(df2,on='customer_id',suffixes=('','_duplicate'))

# %%
df.to_csv('clean.csv')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set(style='whitegrid')

# %%
df['order_date'] = pd.to_datetime(df['order_date'], format='mixed', dayfirst=False)
monthly_sales = df.groupby(df['order_date'].dt.to_period('M'))['sales_per_order'].sum()
monthly_sales.index = monthly_sales.index.to_timestamp()

plt.figure(figsize=(12, 6))
sns.lineplot(data=monthly_sales)
plt.title('Monthly Sales Trend')
plt.xlabel('Month')
plt.ylabel('Total Sales')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='sales_per_order', y='profit_per_order', alpha=0.5)
plt.title('Sales vs. Profit')
plt.xlabel('Sales per Order')
plt.ylabel('Profit per Order')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, x='customer_segment', y='profit_per_order')
plt.title('Profit Distribution by Customer Segment')
plt.xlabel('Customer Segment')
plt.ylabel('Profit per Order')
plt.tight_layout()
plt.show()

# %%
df['shipment_delay'] = df['days_for_shipment_real'] - df['days_for_shipment_scheduled']
plt.figure(figsize=(10, 8))
corr = df[['sales_per_order', 'profit_per_order', 'order_item_discount',
           'order_quantity', 'shipment_delay']].corr()
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f", square=True)
plt.title('Correlation Heatmap of Key Metrics')
plt.tight_layout()
plt.show()

# %%
top_cities = df.groupby('customer_city')['sales_per_order'].sum().nlargest(10)

plt.figure(figsize=(12, 6))
sns.barplot(x=top_cities.values, y=top_cities.index, palette='Blues_r')
plt.title('Top 10 Cities by Total Sales')
plt.xlabel('Total Sales')
plt.ylabel('City')
plt.tight_layout()
plt.show()

# %%
shipping_counts = df['shipping_type'].value_counts()

plt.figure(figsize=(7, 7))
plt.pie(shipping_counts, labels=shipping_counts.index, autopct='%1.1f%%', startangle=140, colors=sns.color_palette('pastel'))
plt.title('Order Distribution by Shipping Type')
plt.axis('equal')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.violinplot(data=df, x='category_name', y='profit_per_order', palette='Set3')
plt.title('Profit Distribution by Product Category')
plt.xlabel('Category')
plt.ylabel('Profit per Order')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-24-e11566d30d3c>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df, x='category_name', y='profit_per_order', palette='Set3')

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['order_quantity'], bins=30, kde=True, color='teal')
plt.title('Order Quantity Distribution')
plt.xlabel('Quantity')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

# %%
sns.pairplot(df[['sales_per_order', 'profit_per_order', 'order_item_discount', 'order_quantity']], corner=True)
plt.suptitle('Pairwise Relationships of Key Metrics', y=1.02)
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.countplot(data=df, x='customer_segment', palette='pastel')
plt.title('Order Count by Customer Segment')
plt.xlabel('Segment')
plt.ylabel('Count')
plt.tight_layout()
plt.show()

# %% [markdown]
# To learn more about accelerating pandas on Colab, see the [10 minute guide](https://colab.research.google.com/github/rapidsai-community/showcase/blob/main/getting_started_tutorials/cudf_pandas_colab_demo.ipynb) or
#  [US stock market data analysis demo](https://colab.research.google.com/github/rapidsai-community/showcase/blob/main/getting_started_tutorials/cudf_pandas_stocks_demo.ipynb).

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## Machine learning
# </div>
#
# With Colab you can import an image dataset, train an image classifier on it, and evaluate the model, all in just [a few lines of code](https://colab.research.google.com/github/tensorflow/docs/blob/master/site/en/tutorials/quickstart/beginner.ipynb).

# %% [markdown]
# Colab is used extensively in the machine learning community with applications including:
# - Getting started with TensorFlow
# - Developing and training neural networks
# - Experimenting with TPUs
# - Disseminating AI research
# - Creating tutorials
#
# To see sample Colab notebooks that demonstrate machine learning applications, see the [machine learning examples](#machine-learning-examples) below.

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## More Resources
#
# ### Working with Notebooks in Colab
#
# </div>
#
# - [Overview of Colab](/notebooks/basic_features_overview.ipynb)
# - [Guide to Markdown](/notebooks/markdown_guide.ipynb)
# - [Importing libraries and installing dependencies](/notebooks/snippets/importing_libraries.ipynb)
# - [Saving and loading notebooks in GitHub](https://colab.research.google.com/github/googlecolab/colabtools/blob/main/notebooks/colab-github-demo.ipynb)
# - [Interactive forms](/notebooks/forms.ipynb)
# - [Interactive widgets](/notebooks/widgets.ipynb)
#
# <div class="markdown-google-sans">
#
# <a name="working-with-data"></a>
# ### Working with Data
# </div>
#
# - [Loading data: Drive, Sheets, and Google Cloud Storage](/notebooks/io.ipynb)
# - [Charts: visualizing data](/notebooks/charts.ipynb)
# - [Getting started with BigQuery](/notebooks/bigquery.ipynb)
#
# <div class="markdown-google-sans">
#
# ### Machine Learning
#
# <div>
#
# These are a few of the notebooks related to Machine Learning, including Google's online Machine Learning course. See the [full course website](https://developers.google.com/machine-learning/crash-course/) for more.
# - [Intro to Pandas DataFrame](https://colab.research.google.com/github/google/eng-edu/blob/main/ml/cc/exercises/pandas_dataframe_ultraquick_tutorial.ipynb)
# - [Intro to RAPIDS cuDF to accelerate pandas](https://nvda.ws/rapids-cudf)
# - [Getting Started with cuML's accelerator mode](https://colab.research.google.com/github/rapidsai-community/showcase/blob/main/getting_started_tutorials/cuml_sklearn_colab_demo.ipynb)
# - [Linear regression with tf.keras using synthetic data](https://colab.research.google.com/github/google/eng-edu/blob/main/ml/cc/exercises/linear_regression_with_synthetic_data.ipynb)
#
# <div class="markdown-google-sans">
#
# <a name="using-accelerated-hardware"></a>
# ### Using Accelerated Hardware
# </div>
#
# - [TensorFlow with GPUs](/notebooks/gpu.ipynb)
# - [TPUs in Colab](/notebooks/tpu.ipynb)

# %% [markdown]
# <div class="markdown-google-sans">
#
# <a name="machine-learning-examples"></a>
#
# ### Featured examples
#
# </div>
#
# - [Retraining an Image Classifier](https://tensorflow.org/hub/tutorials/tf2_image_retraining): Build a Keras model on top of a pre-trained image classifier to distinguish flowers.
# - [Text Classification](https://tensorflow.org/hub/tutorials/tf2_text_classification): Classify IMDB movie reviews as either *positive* or *negative*.
# - [Style Transfer](https://tensorflow.org/hub/tutorials/tf2_arbitrary_image_stylization): Use deep learning to transfer style between images.
# - [Multilingual Universal Sentence Encoder Q&A](https://tensorflow.org/hub/tutorials/retrieval_with_tf_hub_universal_encoder_qa): Use a machine learning model to answer questions from the SQuAD dataset.
# - [Video Interpolation](https://tensorflow.org/hub/tutorials/tweening_conv3d): Predict what happened in a video between the first and the last frame.
